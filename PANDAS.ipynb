# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')

ruta = '/content/drive/MyDrive/DBase.csv'
df = pd.read_csv(ruta)
# Out:
# Mounted at /content/drive

# %%
df.shape
df['Edad_paciente'].describe()
df['Edad_paciente'].hist(bins=20)
df.groupby('Evento_reportado')['Hospitalizacion'].value_counts()
df['Año'].value_counts().sort_index()

# %%
df.describe()
# Out:
#        Semana_epidemiológica          Año  Edad_paciente  Código_Nacionalidad  \
# count            1226.000000  1226.000000    1226.000000               1226.0
# mean               26.475530  2023.982055      21.588091                170.0
# std                14.477111     0.132804      19.520434                  0.0
# min                 1.000000  2023.000000       1.000000                170.0
# 25%                15.000000  2024.000000       7.000000                170.0
# 50%                26.000000  2024.000000      15.000000                170.0
# 75%                38.000000  2024.000000      32.000000                170.0
# max                52.000000  2024.000000      90.000000                170.0
#
#        Codigo Departamento  Código_Municipio  Estrato_socioeconómico  \
# count          1226.000000       1226.000000             1211.000000
# mean             65.721860        449.424144                1.148637
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha_notificación          1226 non-null   object
#  1   Semana_epidemiológica       1226 non-null   int64
#  2   Año                         1226 non-null   int64
#  3   Edad_paciente               1226 non-null   int64
#  4   Código_Nacionalidad         1226 non-null   int64
#  5   Nacionalidad                1226 non-null   object
#  6   Sexo_paciente               1226 non-null   object
#  7   Codigo Departamento         1226 non-null   int64
#  8   Código_Municipio            1226 non-null   int64
#  9   Tipo Seguridad Social       1226 non-null   object
#  10  Estrato_socioeconómico      1211 non-null   float64
#  11  Discapacidad                1226 non-null   object
#  12  Desplazado                  1226 non-null   object
# ...

# %%
df['Evento_reportado'].value_counts()
# Out:
# Evento_reportado
# MALARIA                                                                                                                                   445
# DENGUE                                                                                                                                    222
# VIGILANCIA EN SALUD PÚBLICA DE LA VIOLENCIA DE GÉNERO E INTRAFAMILIAR                                                                     213
# LEISHMANIASIS CUTANEA                                                                                                                      85
# DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS                                                                                                    66
# AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMISORES DE RABIA                                                                               57
# ...

# %%
df['Sexo_paciente'].value_counts()
# Out:
# Sexo_paciente
# F    663
# M    563
# Name: count, dtype: int64

# %%
df['Edad_paciente'].describe()
df['Edad_paciente'].hist(bins=20)
# Out:
# <Axes: >

# %%
df.groupby('Evento_reportado')['Hospitalizacion'].value_counts()
# Out:
# Evento_reportado                                                                                                                        Hospitalizacion
# ACCIDENTE OFIDICO                                                                                                                       SI                   5
#                                                                                                                                         NO                   4
# AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMISORES DE RABIA                                                                            NO                  57
# CÁNCER DE LA MAMA Y CUELLO UTERINO                                                                                                      NO                  12
# CÁNCER EN MENORES DE 18 AÑOS                                                                                                            SI                   1
# ...

# %%
df['Año'].value_counts().sort_index()
# Out:
# Año
# 2023      22
# 2024    1204
# Name: count, dtype: int64
