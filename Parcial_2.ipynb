# %% [markdown]
# <a href="https://colab.research.google.com/github/scuarlus/Ciencia_de_Datos/blob/main/Parcial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pregunta #1

# %%
import matplotlib.pyplot as plt
meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun", "Jul", "Ago", "Sep", "Oct", "Nov", "Dic"]
temperaturas = [22, 24, 27, 30, 32, 35, 34, 33, 30, 27, 24, 22]
plt.plot(meses, temperaturas, marker='o', color='red')
plt.xlabel("Mes")
plt.ylabel("Temperatura (°C)")
plt.title("Temperaturas Media Mensual")
plt.grid(True)
plt.show()

# %% [markdown]
# Pregunta #2

# %%
import seaborn as sns
import pandas as pd
import numpy as np
np.random.seed(0)
df2 = pd.DataFrame({
    'Edad': np.random.randint(18, 60, 20),
    'Ingreso': np.random.randint(1000, 5000, 20),
    'Genero': np.random.choice(['Masculino', 'Femenino'], 20)
})
sns.set_style("whitegrid")
sns.scatterplot(data=df2, x='Edad', y='Ingreso', hue='Genero')
plt.title("Relación Edad-Ingreso")
plt.show()

# %% [markdown]
# Pregunta #3

# %%
import numpy as np
import matplotlib.pyplot as plt

datos = np.random.normal(loc=50, scale=10, size=200)

plt.figure(figsize=(8, 5))
plt.hist(datos, bins=15, color='blue', alpha=0.6, edgecolor='black')

plt.title('Histograma de distribución normal (μ=50, σ=10)', fontsize=14)
plt.xlabel('Valor', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)


plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# Pregunta #4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")


np.random.seed(42)
ninos = np.random.normal(loc=130, scale=10, size=30)
adultos = np.random.normal(loc=170, scale=8, size=30)
adultos_mayores = np.random.normal(loc=165, scale=9, size=30)


df = pd.DataFrame({
    'Altura': np.concatenate([ninos, adultos, adultos_mayores]),
    'Grupo': ['Niños']*30 + ['Adultos']*30 + ['Adultos Mayores']*30
})


plt.figure(figsize=(8, 6))
sns.boxplot(x='Grupo', y='Altura', data=df, palette='Set2', showfliers=True)


plt.title('Comparación de alturas por grupo', fontsize=16)
plt.xlabel('Grupo', fontsize=12)
plt.ylabel('Altura (cm)', fontsize=12)


plt.show()
# Out:
# /tmp/ipython-input-1443388530.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Grupo', y='Altura', data=df, palette='Set2', showfliers=True)

# %% [markdown]
# Pregunta #5

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(42)
meses = pd.date_range("2024-01-01", periods=12, freq="M").strftime('%b')
regiones = ["Norte", "Centro", "Sur"]
datos = []
for mes in meses:
    for region in regiones:
        ventas = np.random.randint(1000, 5000)
        datos.append([mes, region, ventas])

df = pd.DataFrame(datos, columns=["Mes", "Region", "Ventas"])
ventas_totales = df.groupby("Mes", as_index=False)["Ventas"].sum()
ventas_totales["Promedio_movil"] = ventas_totales["Ventas"].rolling(window=3).mean()
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
sns.barplot(data=df, x="Mes", y="Ventas", hue="Region", palette="Set2", ci=None)
plt.plot(
    ventas_totales["Mes"],
    ventas_totales["Promedio_movil"],
    marker="o",
    color="black",
    linewidth=2,
    label="Promedio móvil"
)
plt.ylabel("Ventas")
plt.xlabel("Mes")
plt.title("Ventas mensuales por región con promedio móvil")
plt.legend(title="", labels=["Ventas totales", "Promedio móvil"], loc="upper left")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2182901494.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   meses = pd.date_range("2024-01-01", periods=12, freq="M").strftime('%b')
# /tmp/ipython-input-2182901494.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Mes", y="Ventas", hue="Region", palette="Set2", ci=None)
